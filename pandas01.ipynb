# %% [markdown]
# <a href="https://colab.research.google.com/github/nin844/it_practice/blob/main/pandas01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# csvをデータフレームとして読む
df_population_data = pd.read_csv('/content/drive/My Drive/data.csv', encoding='shift-jis')

# %%
# データの中身を見る
df_population_data
# Out:
#      都道府県コード 都道府県名  元号  和暦（年）   西暦（年）   人口（総数）    人口（男）    人口（女）
# 0          1   北海道  大正    9.0  1920.0  2359183  1244322  1114861
# 1          2   青森県  大正    9.0  1920.0   756454   381293   375161
# 2          3   岩手県  大正    9.0  1920.0   845540   421069   424471
# 3          4   宮城県  大正    9.0  1920.0   961768   485309   476459
# 4          5   秋田県  大正    9.0  1920.0   898537   453682   444855
# ..       ...   ...  ..    ...     ...      ...      ...      ...
# 934       43   熊本県  平成   27.0  2015.0  1786170   841046   945124
# 935       44   大分県  平成   27.0  2015.0  1166338   551932   614406
# 936       45   宮崎県  平成   27.0  2015.0  1104069   519242   584827
# 937       46  鹿児島県  平成   27.0  2015.0  1648177   773061   875116
# 938       47   沖縄県  平成   27.0  2015.0  1433566   704619   728947
#
# [939 rows x 8 columns]

# %%
# データの型を確認する
type('元号')
# Out:
# str

# %%
df_population_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 939 entries, 0 to 938
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   都道府県コード  939 non-null    int64
#  1   都道府県名    939 non-null    object
#  2   元号       939 non-null    object
#  3   和暦（年）    939 non-null    float64
#  4   西暦（年）    939 non-null    float64
#  5   人口（総数）   939 non-null    int64
#  6   人口（男）    939 non-null    int64
#  7   人口（女）    939 non-null    int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 58.8+ KB

# %%
# 表示する列数・行数を変える pandasの設定を変更する
pd.set_option('display.max_columns', 10) 
pd.set_option('display.max_rows',20)

# %%
df_population_data
# Out:
#      都道府県コード 都道府県名  元号  和暦（年）   西暦（年）   人口（総数）    人口（男）    人口（女）
# 0          1   北海道  大正    9.0  1920.0  2359183  1244322  1114861
# 1          2   青森県  大正    9.0  1920.0   756454   381293   375161
# ..       ...   ...  ..    ...     ...      ...      ...      ...
# 937       46  鹿児島県  平成   27.0  2015.0  1648177   773061   875116
# 938       47   沖縄県  平成   27.0  2015.0  1433566   704619   728947
#
# [939 rows x 8 columns]

# %%
#　表示行数を元に戻す
pd.reset_option('display.max_rows')
df_population_data
# Out:
#      都道府県コード 都道府県名  元号  和暦（年）   西暦（年）   人口（総数）    人口（男）    人口（女）
# 0          1   北海道  大正    9.0  1920.0  2359183  1244322  1114861
# 1          2   青森県  大正    9.0  1920.0   756454   381293   375161
# 2          3   岩手県  大正    9.0  1920.0   845540   421069   424471
# 3          4   宮城県  大正    9.0  1920.0   961768   485309   476459
# 4          5   秋田県  大正    9.0  1920.0   898537   453682   444855
# ..       ...   ...  ..    ...     ...      ...      ...      ...
# 934       43   熊本県  平成   27.0  2015.0  1786170   841046   945124
# 935       44   大分県  平成   27.0  2015.0  1166338   551932   614406
# 936       45   宮崎県  平成   27.0  2015.0  1104069   519242   584827
# 937       46  鹿児島県  平成   27.0  2015.0  1648177   773061   875116
# 938       47   沖縄県  平成   27.0  2015.0  1433566   704619   728947
#
# [939 rows x 8 columns]

# %%
# 最初の10行を表示する
df_population_data.head(10)
# Out:
#     都道府県コード 都道府県名  元号  和暦（年）   西暦（年）   人口（総数）    人口（男）    人口（女）
# 0         1   北海道  大正    9.0  1920.0  2359183  1244322  1114861
# 1         2   青森県  大正    9.0  1920.0   756454   381293   375161
# ..      ...   ...  ..    ...     ...      ...      ...      ...
# 8         9   栃木県  大正    9.0  1920.0  1046479   514255   532224
# 9        10   群馬県  大正    9.0  1920.0  1052610   514106   538504
#
# [10 rows x 8 columns]

# %%
# 最後の5行を表示する 省略すると5になる
df_population_data.tail()
# Out:
#      都道府県コード 都道府県名  元号  和暦（年）   西暦（年）   人口（総数）   人口（男）   人口（女）
# 934       43   熊本県  平成   27.0  2015.0  1786170  841046  945124
# 935       44   大分県  平成   27.0  2015.0  1166338  551932  614406
# 936       45   宮崎県  平成   27.0  2015.0  1104069  519242  584827
# 937       46  鹿児島県  平成   27.0  2015.0  1648177  773061  875116
# 938       47   沖縄県  平成   27.0  2015.0  1433566  704619  728947

# %%
# ランダムに10行取ってくる
df_population_data.sample(10)
# Out:
#      都道府県コード 都道府県名  元号  和暦（年）   西暦（年）   人口（総数）    人口（男）    人口（女）
# 504       36   徳島県  昭和   45.0  1970.0   791111   376729   414382
# 405       31   鳥取県  昭和   35.0  1960.0   599135   286716   312419
# ..       ...   ...  ..    ...     ...      ...      ...      ...
# 621       12   千葉県  昭和   60.0  1985.0  5148163  2588365  2559798
# 825       28   兵庫県  平成   17.0  2005.0  5590601  2680288  2910313
#
# [10 rows x 8 columns]

# %%
# 統計量を見る
df_population_data.describe().round(0)
# Out:
#        都道府県コード  和暦（年）   西暦（年）      人口（総数）      人口（男）      人口（女）
# count    939.0  939.0   939.0       939.0      939.0      939.0
# mean      24.0   25.0  1968.0   2104324.0  1033620.0  1070703.0
# std       14.0   17.0    29.0   1970612.0   989010.0   982617.0
# min        1.0    2.0  1920.0    454675.0   222802.0   231873.0
# 25%       12.0   11.0  1942.0   1000186.0   484636.0   516088.0
# 50%       24.0   22.0  1970.0   1461197.0   702697.0   758321.0
# 75%       36.0   38.0  1992.0   2144998.0  1044104.0  1097804.0
# max       47.0   60.0  2015.0  13515271.0  6666690.0  6848581.0

# %%
# グループごとに集計する GropuBy
df_population_data.groupby(by='都道府県名').mean()[['人口（総数）','人口（男）','人口（女）']].round(0)
# Out:
#           人口（総数）      人口（男）      人口（女）
# 都道府県名
# 三重県    1534021.0   743367.0   790655.0
# 京都府    2135318.0  1044094.0  1091224.0
# 佐賀県     830574.0   395551.0   435024.0
# 兵庫県    4233525.0  2067583.0  2165942.0
# 北海道    4606104.0  2272235.0  2333869.0
# ...          ...        ...        ...
# 静岡県    2892099.0  1422674.0  1469426.0
# 香川県     905636.0   437365.0   468271.0
# 高知県     785564.0   376501.0   409063.0
# 鳥取県     566553.0   271488.0   295065.0
# 鹿児島県   1718576.0   813283.0   905294.0
#
# [47 rows x 3 columns]

# %%
# 並べ替えをする Sort
df_population_mean = df_population_data.groupby(by='都道府県名').mean()[['人口（総数）','人口（男）','人口（女）']].round(0)
df_population_mean.sort_values(by='人口（総数）', ascending = False)
# Out:
#           人口（総数）      人口（男）      人口（女）
# 都道府県名
# 東京都    9357393.0  4740644.0  4616749.0
# 大阪府    6380772.0  3167759.0  3213014.0
# 神奈川県   5072212.0  2582037.0  2490175.0
# 愛知県    4938295.0  2457583.0  2480712.0
# 北海道    4606104.0  2272235.0  2333869.0
# ...          ...        ...        ...
# 高知県     785564.0   376501.0   409063.0
# 島根県     783345.0   378945.0   404400.0
# 山梨県     775774.0   378483.0   397291.0
# 福井県     743214.0   359213.0   384001.0
# 鳥取県     566553.0   271488.0   295065.0
#
# [47 rows x 3 columns]

# %%
# データの結合をする:
left = pd.DataFrame({'name':['aaa','bbb','ccc','ddd'], 'age':[24,33,27,42]})
right = pd.DataFrame({'name':['eee','bbb','aaa','fff','ddd'], 'group':['x','y','y','x','x']})

# %%
left
right
# Out:
#   name group
# 0  eee     x
# 1  bbb     y
# 2  aaa     y
# 3  fff     x
# 4  ddd     x

# %%
pd.merge(left,right)
# Out:
#   name  age group
# 0  aaa   24     y
# 1  bbb   33     y
# 2  ddd   42     x

# %%
# merge で結合　両方に存在する共通キーを元に結合
pd.merge(left,right, how='outer')
# Out:
#   name   age group
# 0  aaa  24.0     y
# 1  bbb  33.0     y
# 2  ccc  27.0   NaN
# 3  ddd  42.0     x
# 4  eee   NaN     x
# 5  fff   NaN     x

# %%
# キーに関係なくタテに結合
pd.concat([left,right])
# Out:
#   name   age group
# 0  aaa  24.0   NaN
# 1  bbb  33.0   NaN
# 2  ccc  27.0   NaN
# 3  ddd  42.0   NaN
# 0  eee   NaN     x
# 1  bbb   NaN     y
# 2  aaa   NaN     y
# 3  fff   NaN     x
# 4  ddd   NaN     x

# %%
# 横方向に連結
pd.concat([left,right], axis=1)
# Out:
#   name   age name group
# 0  aaa  24.0  eee     x
# 1  bbb  33.0  bbb     y
# 2  ccc  27.0  aaa     y
# 3  ddd  42.0  fff     x
# 4  NaN   NaN  ddd     x

# %%
df_population_data
# Out:
#      都道府県コード 都道府県名  元号  和暦（年）   西暦（年）   人口（総数）    人口（男）    人口（女）
# 0          1   北海道  大正    9.0  1920.0  2359183  1244322  1114861
# 1          2   青森県  大正    9.0  1920.0   756454   381293   375161
# 2          3   岩手県  大正    9.0  1920.0   845540   421069   424471
# 3          4   宮城県  大正    9.0  1920.0   961768   485309   476459
# 4          5   秋田県  大正    9.0  1920.0   898537   453682   444855
# ..       ...   ...  ..    ...     ...      ...      ...      ...
# 934       43   熊本県  平成   27.0  2015.0  1786170   841046   945124
# 935       44   大分県  平成   27.0  2015.0  1166338   551932   614406
# 936       45   宮崎県  平成   27.0  2015.0  1104069   519242   584827
# 937       46  鹿児島県  平成   27.0  2015.0  1648177   773061   875116
# 938       47   沖縄県  平成   27.0  2015.0  1433566   704619   728947
#
# [939 rows x 8 columns]

# %%
# グラフ化
import matplotlib
matplotlib.rcParams['font.family']='Arial Unicode MS'
df_population_data[df_population_data['都道府県名']=='東京都'][['人口（男）','人口（女）']].plot(color=['skyblue','pink'])
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21475 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 65288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 30007 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 65289 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22899 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 21475 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 65288 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 30007 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 65289 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 22899 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df_population_data[df_population_data['都道府県名']=='東京都'][['人口（男）','人口（女）']].plot(kind='bar',color=['skyblue','pink'])
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 21475 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 65288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 30007 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 65289 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 22899 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 21475 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 65288 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 30007 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 65289 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 22899 missing from current font.
#   font.set_text(s, 0, flags=flags)
